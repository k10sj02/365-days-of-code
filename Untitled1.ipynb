# %% [markdown]
# <a href="https://colab.research.google.com/github/k10sj02/365-days-of-code/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nksn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2330091065.py in <cell line: 0>()
# ----> 1 nksn
#
# NameError: name 'nksn' is not defined

# %%
knkn
