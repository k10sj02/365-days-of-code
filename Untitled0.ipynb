# %% [markdown]
# <a href="https://colab.research.google.com/github/k10sj02/365-days-of-code/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cbkcndkn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1579382790.py in <cell line: 0>()
# ----> 1 cbkcndkn
#
# NameError: name 'cbkcndkn' is not defined

# %%
bjbjb
